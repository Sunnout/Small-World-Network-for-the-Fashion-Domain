# %%
import DataManager
print("ola")
# Out:
# ola

# %%
imgs = DataManager.get_img_names()

# %%
import FeatureExtractor as fe
from ImageProcessor import ImageProcessor
#import SimilarityCalculator
from skimage import img_as_ubyte

img = DataManager.get_rand_image()
norm_img = ImageProcessor.center_crop_image(img)
fe.my_hog(norm_img)
img_int = img_as_ubyte(norm_img)
fe.hoc(img_int)
# Out:
# (array([    1,     4,     0, ...,     0,     0, 29543], dtype=int64),
#  array([ 308.        ,  308.92456055,  309.84912109, ..., 4093.15087891,
#         4094.07543945, 4095.        ]))
