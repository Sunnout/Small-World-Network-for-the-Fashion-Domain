# %%
import DataManager
print("ola")
# Out:
# Using TensorFlow backend.
# ola

# %%
imgs = DataManager.get_img_names()
# Out:
# ['img_00000003.jpg', 'img_00000015.jpg', 'img_00000001.jpg', 'img_00000005.jpg', 'img_00000006.jpg', 'img_00000071.jpg', 'img_00000043.jpg', 'img_00000052.jpg', 'img_00000020.jpg', 'img_00000032.jpg', 'img_00000033.jpg']

# %%
import FeatureExtractor as fe
import SimilarityCalc
from skimage import img_as_ubyte

img = DataManager.get_img("img_00000003.jpg")
norm_img = DataManager.center_crop_image(img)
fe.my_hog(norm_img)
img_int = img_as_ubyte(norm_img)
fe.hoc(img_int)
# Out:
# (array([   22,     8,     0, ...,     0,   725, 23328]),
#  array([  19.        ,   19.99511719,   20.99023438, ..., 4093.00976562,
#         4094.00488281, 4095.        ]))
