# %%
from PWPro import DataManager
print("Import Finished!")
# Out:
# Import Finished!

# %%
imgs = DataManager.get_img_names()

# %%
from PWPro import FeatureExtractor as fe
from PWPro.ImageProcessor import ImageProcessor
#import SimilarityCalculator
from skimage import img_as_ubyte

img = DataManager.get_rand_image()
norm_img = ImageProcessor.center_crop_image(img)

fd, hog_image = fe.my_hog(norm_img)
fe.plot_hog(fd, hog_image, norm_img)

img_int = img_as_ubyte(norm_img)

hist_r, bins_r = fe.hoc(img_int)
fe.plot_hoc(hist_r, bins_r)
